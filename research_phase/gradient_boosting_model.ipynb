# %%
! pip install feature_engine
# Out:
# Requirement already satisfied: feature_engine in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (0.3.1)
# Requirement already satisfied: statsmodels>=0.8.0 in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from feature_engine) (0.10.1)
# Requirement already satisfied: numpydoc>=0.6.0 in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from feature_engine) (0.9.2)
# Requirement already satisfied: pandas>=0.23.0 in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from feature_engine) (0.23.4)
# Requirement already satisfied: scipy>=0.19.0 in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from feature_engine) (1.3.1)
# Requirement already satisfied: numpy>=1.12.1 in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from feature_engine) (1.18.1)
# Requirement already satisfied: scikit-learn>=0.18.1 in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from feature_engine) (0.22.1)
# Requirement already satisfied: patsy>=0.4.0 in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from statsmodels>=0.8.0->feature_engine) (0.5.1)
# Requirement already satisfied: Jinja2>=2.3 in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from numpydoc>=0.6.0->feature_engine) (2.10.3)
# Requirement already satisfied: sphinx>=1.6.5 in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from numpydoc>=0.6.0->feature_engine) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.5.0 in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from pandas>=0.23.0->feature_engine) (2.8.0)
# Requirement already satisfied: pytz>=2011k in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from pandas>=0.23.0->feature_engine) (2019.3)
# Requirement already satisfied: joblib>=0.11 in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from scikit-learn>=0.18.1->feature_engine) (0.14.1)
# Requirement already satisfied: six in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from patsy>=0.4.0->statsmodels>=0.8.0->feature_engine) (1.13.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from Jinja2>=2.3->numpydoc>=0.6.0->feature_engine) (1.1.1)
# Requirement already satisfied: snowballstemmer>=1.1 in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from sphinx>=1.6.5->numpydoc>=0.6.0->feature_engine) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from sphinx>=1.6.5->numpydoc>=0.6.0->feature_engine) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from sphinx>=1.6.5->numpydoc>=0.6.0->feature_engine) (1.0.2)
# Requirement already satisfied: sphinxcontrib-applehelp in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from sphinx>=1.6.5->numpydoc>=0.6.0->feature_engine) (1.0.1)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from sphinx>=1.6.5->numpydoc>=0.6.0->feature_engine) (0.7.12)
# Requirement already satisfied: packaging in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from sphinx>=1.6.5->numpydoc>=0.6.0->feature_engine) (20.0)
# Requirement already satisfied: requests>=2.5.0 in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from sphinx>=1.6.5->numpydoc>=0.6.0->feature_engine) (2.22.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from sphinx>=1.6.5->numpydoc>=0.6.0->feature_engine) (1.1.3)
# Requirement already satisfied: Pygments>=2.0 in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from sphinx>=1.6.5->numpydoc>=0.6.0->feature_engine) (2.5.2)
# Requirement already satisfied: sphinxcontrib-jsmath in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from sphinx>=1.6.5->numpydoc>=0.6.0->feature_engine) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from sphinx>=1.6.5->numpydoc>=0.6.0->feature_engine) (1.0.2)
# Requirement already satisfied: babel!=2.0,>=1.3 in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from sphinx>=1.6.5->numpydoc>=0.6.0->feature_engine) (2.8.0)
# Requirement already satisfied: docutils>=0.12 in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from sphinx>=1.6.5->numpydoc>=0.6.0->feature_engine) (0.15.2)
# Requirement already satisfied: imagesize in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from sphinx>=1.6.5->numpydoc>=0.6.0->feature_engine) (1.2.0)
# Requirement already satisfied: setuptools in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from sphinx>=1.6.5->numpydoc>=0.6.0->feature_engine) (44.0.0.post20200106)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from packaging->sphinx>=1.6.5->numpydoc>=0.6.0->feature_engine) (2.4.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from requests>=2.5.0->sphinx>=1.6.5->numpydoc>=0.6.0->feature_engine) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from requests>=2.5.0->sphinx>=1.6.5->numpydoc>=0.6.0->feature_engine) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from requests>=2.5.0->sphinx>=1.6.5->numpydoc>=0.6.0->feature_engine) (1.25.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages (from requests>=2.5.0->sphinx>=1.6.5->numpydoc>=0.6.0->feature_engine) (2019.11.28)

# %%
from math import sqrt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# for the ML pipeline
from sklearn.model_selection import train_test_split
from sklearn.impute  import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import (
    mean_squared_error,
    r2_score, 
    mean_absolute_error
)

# from sklearn.pipeline import Pipeline
# from sklearn.compose import ColumnTransformer

from feature_engine.categorical_encoders import RareLabelCategoricalEncoder

# to visualise al the columns in the dataframe
pd.pandas.set_option('display.max_columns', None)

# %%
# load dataset
# remember to download the data set  from Kaggle and save it into 
# the same folder from where you run this notebook

data = pd.read_csv('houseprice.csv')

print(data.shape)
data.head()
# Out:
# (1460, 81)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %% [markdown]
# ### Separate dataset into train and test
#
# Before beginning to engineer our features, it is important to separate our data intro training and testing set. This is to avoid over-fitting. This step involves randomness, therefore, we need to set the seed.

# %%
# Let's separate into train and test set

X_train, X_test, y_train, y_test = train_test_split(
    data.drop('SalePrice', axis=1), # predictors
    data.SalePrice, # target
    test_size=0.1,
    random_state=0)  # for reproducibility

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((1314, 80), (146, 80), (1314,), (146,))

# %% [markdown]
# ### Missing values

# %%
# make lists capturing the different variables types in our dataset:
# -----------------------------------------
# one list to capture date variables
# one list to capture categorical variables
# one list to capture numerical variables

vars_dates = ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt']
vars_cat = [var for var in X_train.columns if X_train[var].dtypes == 'O']
vars_num = [var for var in X_train.columns if X_train[var].dtypes !=
            'O' and var not in ['Id']]

# %%
X_train[vars_dates].isnull()
# Out:
#       YearBuilt  YearRemodAdd  GarageYrBlt
# 930       False         False        False
# 656       False         False        False
# 45        False         False        False
# 1348      False         False        False
# 55        False         False        False
# 1228      False         False        False
# 963       False         False        False
# 921       False         False         True
# 458       False         False        False
# 1386      False         False        False
# 479       False         False        False
# 1244      False         False        False
# 613       False         False         True
# 1124      False         False        False
# 223       False         False        False
# 1233      False         False        False
# 989       False         False        False
# 713       False         False        False
# 1002      False         False        False
# 108       False         False         True
# 743       False         False        False
# 517       False         False        False
# 333       False         False        False
# 1108      False         False        False
# 260       False         False        False
# 795       False         False        False
# 1042      False         False        False
# 695       False         False        False
# 422       False         False        False
# 574       False         False        False
# ...         ...           ...          ...
# 1435      False         False        False
# 1201      False         False        False
# 99        False         False         True
# 850       False         False        False
# 448       False         False        False
# 755       False         False        False
# 976       False         False         True
# 115       False         False        False
# 777       False         False        False
# 72        False         False        False
# 845       False         False        False
# 537       False         False        False
# 849       False         False        False
# 174       False         False        False
# 87        False         False        False
# 551       False         False        False
# 705       False         False         True
# 314       False         False        False
# 1420      False         False        False
# 600       False         False        False
# 1094      False         False        False
# 599       False         False        False
# 277       False         False        False
# 1033      False         False        False
# 1383      False         False        False
# 763       False         False        False
# 835       False         False        False
# 1216      False         False        False
# 559       False         False        False
# 684       False         False        False
#
# [1314 rows x 3 columns]

# %%
# check for missing values in our date variables

# false →　0, True→1の平均
# nanの割合
X_train[vars_dates].isnull().mean().sort_values(ascending=False)
# Out:
# GarageYrBlt     0.056317
# YearRemodAdd    0.000000
# YearBuilt       0.000000
# dtype: float64

# %%
X_train[vars_dates].isnull()['GarageYrBlt'].value_counts()
# Out:
# False    1240
# True       74
# Name: GarageYrBlt, dtype: int64

# %%
74/(1240 + 74)
# Out:
# 0.0563165905631659

# %%
# check for missing values in our numerical variables

X_train[vars_num].isnull().mean().sort_values(ascending=False)
# Out:
# LotFrontage      0.177321
# GarageYrBlt      0.056317
# MasVnrArea       0.004566
# YrSold           0.000000
# BsmtFinSF2       0.000000
# LowQualFinSF     0.000000
# 2ndFlrSF         0.000000
# 1stFlrSF         0.000000
# TotalBsmtSF      0.000000
# BsmtUnfSF        0.000000
# BsmtFinSF1       0.000000
# BsmtFullBath     0.000000
# YearRemodAdd     0.000000
# YearBuilt        0.000000
# OverallCond      0.000000
# OverallQual      0.000000
# LotArea          0.000000
# GrLivArea        0.000000
# BsmtHalfBath     0.000000
# MoSold           0.000000
# WoodDeckSF       0.000000
# MiscVal          0.000000
# PoolArea         0.000000
# ScreenPorch      0.000000
# 3SsnPorch        0.000000
# EnclosedPorch    0.000000
# OpenPorchSF      0.000000
# GarageArea       0.000000
# FullBath         0.000000
# GarageCars       0.000000
# Fireplaces       0.000000
# TotRmsAbvGrd     0.000000
# KitchenAbvGr     0.000000
# BedroomAbvGr     0.000000
# HalfBath         0.000000
# MSSubClass       0.000000
# dtype: float64

# %%
# check for missing values in our categorical variables

X_train[vars_cat].isnull().mean().sort_values(ascending=False)
# Out:
# PoolQC           0.995434
# MiscFeature      0.961187
# Alley            0.938356
# Fence            0.814307
# FireplaceQu      0.472603
# GarageCond       0.056317
# GarageQual       0.056317
# GarageFinish     0.056317
# GarageType       0.056317
# BsmtFinType2     0.025114
# BsmtExposure     0.025114
# BsmtFinType1     0.024353
# BsmtQual         0.024353
# BsmtCond         0.024353
# MasVnrType       0.004566
# Electrical       0.000761
# Condition2       0.000000
# Condition1       0.000000
# Neighborhood     0.000000
# LandSlope        0.000000
# BldgType         0.000000
# LandContour      0.000000
# LotConfig        0.000000
# Utilities        0.000000
# RoofStyle        0.000000
# LotShape         0.000000
# Street           0.000000
# HouseStyle       0.000000
# SaleCondition    0.000000
# RoofMatl         0.000000
# Exterior1st      0.000000
# Exterior2nd      0.000000
# ExterQual        0.000000
# ExterCond        0.000000
# Foundation       0.000000
# SaleType         0.000000
# Heating          0.000000
# HeatingQC        0.000000
# CentralAir       0.000000
# KitchenQual      0.000000
# Functional       0.000000
# PavedDrive       0.000000
# MSZoning         0.000000
# dtype: float64

# %%
# to_frame()
# X_train[['LotFrontage']]と同じ
X_train['LotFrontage'].to_frame()
# Out:
#       LotFrontage
# 930          73.0
# 656          72.0
# 45           61.0
# 1348          NaN
# 55          100.0
# 1228         65.0
# 963         122.0
# 921          67.0
# 458           NaN
# 1386         80.0
# 479          50.0
# 1244          NaN
# 613          70.0
# 1124          NaN
# 223          70.0
# 1233          NaN
# 989          65.0
# 713          60.0
# 1002         75.0
# 108          85.0
# 743          70.0
# 517          79.0
# 333          59.0
# 1108          NaN
# 260         120.0
# 795          70.0
# 1042         34.0
# 695          54.0
# 422         100.0
# 574          70.0
# ...           ...
# 1435         80.0
# 1201         80.0
# 99           77.0
# 850          36.0
# 448          50.0
# 755          34.0
# 976          51.0
# 115          34.0
# 777         100.0
# 72           74.0
# 845           NaN
# 537           NaN
# 849          80.0
# 174          47.0
# 87           40.0
# 551          50.0
# 705          70.0
# 314          60.0
# 1420         90.0
# 600          74.0
# 1094         74.0
# 599          24.0
# 277         140.0
# 1033          NaN
# 1383          NaN
# 763          82.0
# 835          60.0
# 1216         68.0
# 559           NaN
# 684          58.0
#
# [1314 rows x 1 columns]

# %%
# removing missing data
# --------------------
# imputation numerical variables
imputer = SimpleImputer(strategy='constant', fill_value=-1)
X_train['LotFrontage'] = imputer.fit_transform(X_train['LotFrontage'].to_frame())
X_test['LotFrontage'] = imputer.transform(X_test['LotFrontage'].to_frame())

imputer = SimpleImputer(strategy='most_frequent')
X_train[vars_num] = imputer.fit_transform(X_train[vars_num])
X_test[vars_num] = imputer.transform(X_test[vars_num])

# %%
# imputation categorical variables
imputer = SimpleImputer(strategy='constant', fill_value='missing')
X_train[vars_cat] = imputer.fit_transform(X_train[vars_cat])
X_test[vars_cat] = imputer.transform(X_test[vars_cat])

# %% [markdown]
# ### Temporal variables

# %%
X_train[['YrSold','YearBuilt', 'YearRemodAdd', 'GarageYrBlt' ]]
# Out:
#       YrSold  YearBuilt  YearRemodAdd  GarageYrBlt
# 930   2009.0     2007.0        2007.0       2007.0
# 656   2008.0     1959.0        2006.0       1959.0
# 45    2010.0     2005.0        2005.0       2005.0
# 1348  2007.0     1998.0        1998.0       1998.0
# 55    2008.0     1964.0        1964.0       1964.0
# 1228  2008.0     2008.0        2008.0       2008.0
# 963   2009.0     2007.0        2007.0       2007.0
# 921   2008.0     1900.0        2003.0       2005.0
# 458   2008.0     1925.0        1996.0       1925.0
# 1386  2006.0     1978.0        1978.0       1978.0
# 479   2007.0     1937.0        2000.0       1995.0
# 1244  2006.0     1929.0        1950.0       1931.0
# 613   2007.0     2007.0        2007.0       2005.0
# 1124  2007.0     1992.0        1992.0       1992.0
# 223   2009.0     1971.0        1971.0       1989.0
# 1233  2010.0     1959.0        1959.0       1959.0
# 989   2006.0     2006.0        2006.0       2006.0
# 713   2006.0     1970.0        1970.0       1970.0
# 1002  2008.0     2006.0        2006.0       2006.0
# 108   2007.0     1919.0        2005.0       2005.0
# 743   2009.0     1963.0        1999.0       1997.0
# 517   2009.0     1996.0        1997.0       1996.0
# 333   2008.0     2004.0        2004.0       2004.0
# 1108  2007.0     2000.0        2000.0       2000.0
# 260   2009.0     1962.0        1962.0       1991.0
# 795   2010.0     1980.0        1981.0       1980.0
# 1042  2009.0     2005.0        2005.0       2005.0
# 695   2006.0     1987.0        1987.0       1987.0
# 422   2008.0     1954.0        1954.0       1954.0
# 574   2007.0     1971.0        2005.0       1971.0
# ...      ...        ...           ...          ...
# 1435  2008.0     1962.0        2005.0       1962.0
# 1201  2009.0     1998.0        1998.0       1998.0
# 99    2010.0     1959.0        1959.0       2005.0
# 850   2007.0     2003.0        2003.0       2003.0
# 448   2006.0     1937.0        1950.0       1937.0
# 755   2009.0     1999.0        1999.0       1999.0
# 976   2006.0     1923.0        1958.0       2005.0
# 115   2007.0     1999.0        1999.0       1999.0
# 777   2006.0     1974.0        1974.0       1974.0
# 72    2009.0     1998.0        1998.0       1998.0
# 845   2007.0     1975.0        1981.0       1975.0
# 537   2008.0     1972.0        1972.0       1980.0
# 849   2007.0     1976.0        1994.0       1976.0
# 174   2008.0     1986.0        1986.0       1986.0
# 87    2009.0     2009.0        2009.0       2009.0
# 551   2008.0     1957.0        1957.0       1957.0
# 705   2010.0     1930.0        1950.0       2005.0
# 314   2006.0     1925.0        1990.0       1925.0
# 1420  2006.0     1968.0        1968.0       1968.0
# 600   2006.0     2005.0        2005.0       2003.0
# 1094  2010.0     1956.0        2000.0       1956.0
# 599   2008.0     1980.0        1980.0       1980.0
# 277   2010.0     1951.0        1951.0       1951.0
# 1033  2006.0     2002.0        2002.0       2002.0
# 1383  2007.0     1918.0        2007.0       2007.0
# 763   2009.0     1999.0        1999.0       1999.0
# 835   2010.0     1950.0        1995.0       1996.0
# 1216  2010.0     1978.0        1978.0       1978.0
# 559   2006.0     2003.0        2004.0       2003.0
# 684   2010.0     1998.0        1998.0       1998.0
#
# [1314 rows x 4 columns]

# %%
# let's create new temporal features from our date variables


def elapsed_years(df, var):
    # capture difference between year variable and year the house was sold
    df[var] = df['YrSold'] - df[var]
    return df

# %%
for var in ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt']:
    X_train = elapsed_years(X_train, var)
    X_test = elapsed_years(X_test, var)

# %%
# check that test set does not contain null values in the engineered variables
[vr for var in ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt'] if X_test[var].isnull().sum()>0]
# Out:
# []

# %% [markdown]
# ### Categorical variable encoding

# %%
[var for var in X_train.columns if X_train[var].isnull().sum()>0]
# Out:
# []

# %%
[var for var in X_train.columns if X_test[var].isnull().sum()>0]
# Out:
# []

# %%
X_train.shape
# Out:
# (1314, 80)

# %%
for i in vars_cat:
    print(X_train[i].value_counts())
    print("=====")
# Out:
# RL         1036
# RM          197
# FV           55
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64
# =====
# Pave    1309
# Grvl       5
# Name: Street, dtype: int64
# =====
# missing    1233
# Grvl         45
# Pave         36
# Name: Alley, dtype: int64
# =====
# Reg    829
# IR1    440
# IR2     35
# IR3     10
# Name: LotShape, dtype: int64
# =====
# Lvl    1181
# Bnk      56
# HLS      43
# Low      34
# Name: LandContour, dtype: int64
# =====
# AllPub    1313
# NoSeWa       1
# Name: Utilities, dtype: int64
# =====
# Inside     958
# Corner     224
# CulDSac     86
# FR2         43
# FR3          3
# Name: LotConfig, dtype: int64
# =====
# Gtl    1239
# Mod      62
# Sev      13
# Name: LandSlope, dtype: int64
# =====
# NAmes      201
# CollgCr    135
# OldTown    102
# Edwards     88
# Somerst     75
# NridgHt     71
# Gilbert     69
# Sawyer      67
# NWAmes      64
# BrkSide     53
# SawyerW     52
# Crawfor     46
# Mitchel     46
# Timber      36
# NoRidge     35
# IDOTRR      33
# ClearCr     26
# SWISU       24
# StoneBr     23
# Blmngtn     16
# MeadowV     16
# BrDale      15
# Veenker     11
# NPkVill      8
# Blueste      2
# Name: Neighborhood, dtype: int64
# =====
# Norm      1137
# Feedr       71
# Artery      40
# RRAn        22
# PosN        19
# RRAe        11
# PosA         8
# RRNn         4
# RRNe         2
# Name: Condition1, dtype: int64
# =====
# Norm      1303
# Feedr        5
# PosN         2
# PosA         1
# RRNn         1
# RRAe         1
# Artery       1
# Name: Condition2, dtype: int64
# =====
# 1Fam      1099
# TwnhsE     103
# Duplex      44
# Twnhs       40
# 2fmCon      28
# Name: BldgType, dtype: int64
# =====
# 1Story    652
# 2Story    401
# 1.5Fin    141
# SLvl       60
# SFoyer     28
# 1.5Unf     13
# 2.5Unf     11
# 2.5Fin      8
# Name: HouseStyle, dtype: int64
# =====
# Gable      1021
# Hip         261
# Flat         12
# Gambrel      11
# Mansard       7
# Shed          2
# Name: RoofStyle, dtype: int64
# =====
# CompShg    1289
# Tar&Grv      10
# WdShngl       6
# WdShake       5
# Membran       1
# Roll          1
# ClyTile       1
# Metal         1
# Name: RoofMatl, dtype: int64
# =====
# VinylSd    463
# HdBoard    197
# Wd Sdng    188
# MetalSd    187
# Plywood    102
# CemntBd     58
# BrkFace     48
# Stucco      24
# WdShing     22
# AsbShng     19
# Stone        2
# BrkComm      1
# CBlock       1
# AsphShn      1
# ImStucc      1
# Name: Exterior1st, dtype: int64
# =====
# VinylSd    452
# Wd Sdng    183
# HdBoard    183
# MetalSd    182
# Plywood    136
# CmentBd     57
# Wd Shng     33
# BrkFace     24
# Stucco      23
# AsbShng     19
# ImStucc      8
# Brk Cmn      5
# Stone        4
# AsphShn      3
# Other        1
# CBlock       1
# Name: Exterior2nd, dtype: int64
# =====
# None       784
# BrkFace    390
# Stone      121
# BrkCmn      13
# missing      6
# Name: MasVnrType, dtype: int64
# =====
# TA    814
# Gd    440
# Ex     47
# Fa     13
# Name: ExterQual, dtype: int64
# =====
# TA    1154
# Gd     130
# Fa      26
# Ex       3
# Po       1
# Name: ExterCond, dtype: int64
# =====
# PConc     575
# CBlock    573
# BrkTil    137
# Slab       21
# Stone       6
# Wood        2
# Name: Foundation, dtype: int64
# =====
# TA         589
# Gd         552
# Ex         107
# Fa          34
# missing     32
# Name: BsmtQual, dtype: int64
# =====
# TA         1177
# Gd           60
# Fa           43
# missing      32
# Po            2
# Name: BsmtCond, dtype: int64
# =====
# No         860
# Av         198
# Gd         120
# Mn         103
# missing     33
# Name: BsmtExposure, dtype: int64
# =====
# Unf        393
# GLQ        372
# ALQ        198
# BLQ        135
# Rec        120
# LwQ         64
# missing     32
# Name: BsmtFinType1, dtype: int64
# =====
# Unf        1131
# LwQ          46
# Rec          45
# missing      33
# BLQ          31
# ALQ          17
# GLQ          11
# Name: BsmtFinType2, dtype: int64
# =====
# GasA     1284
# GasW       16
# Grav        7
# Wall        4
# OthW        2
# Floor       1
# Name: Heating, dtype: int64
# =====
# Ex    666
# TA    378
# Gd    224
# Fa     45
# Po      1
# Name: HeatingQC, dtype: int64
# =====
# Y    1224
# N      90
# Name: CentralAir, dtype: int64
# =====
# SBrkr      1193
# FuseA        90
# FuseF        26
# FuseP         3
# missing       1
# Mix           1
# Name: Electrical, dtype: int64
# =====
# TA    664
# Gd    522
# Ex     91
# Fa     37
# Name: KitchenQual, dtype: int64
# =====
# Typ     1223
# Min2      33
# Min1      27
# Mod       15
# Maj1      11
# Maj2       4
# Sev        1
# Name: Functional, dtype: int64
# =====
# missing    621
# Gd         339
# TA         284
# Fa          30
# Ex          21
# Po          19
# Name: FireplaceQu, dtype: int64
# =====
# Attchd     782
# Detchd     346
# BuiltIn     83
# missing     74
# Basment     16
# CarPort      7
# 2Types       6
# Name: GarageType, dtype: int64
# =====
# Unf        541
# RFn        383
# Fin        316
# missing     74
# Name: GarageFinish, dtype: int64
# =====
# TA         1178
# missing      74
# Fa           45
# Gd           11
# Ex            3
# Po            3
# Name: GarageQual, dtype: int64
# =====
# TA         1190
# missing      74
# Fa           33
# Gd            8
# Po            7
# Ex            2
# Name: GarageCond, dtype: int64
# =====
# Y    1201
# N      88
# P      25
# Name: PavedDrive, dtype: int64
# =====
# missing    1308
# Gd            3
# Fa            2
# Ex            1
# Name: PoolQC, dtype: int64
# =====
# missing    1070
# MnPrv       131
# GdPrv        55
# GdWo         48
# MnWw         10
# Name: Fence, dtype: int64
# =====
# missing    1263
# Shed         46
# Othr          2
# Gar2          2
# TenC          1
# Name: MiscFeature, dtype: int64
# =====
# WD       1144
# New       108
# COD        38
# ConLD       7
# ConLw       5
# ConLI       5
# CWD         3
# Con         2
# Oth         2
# Name: SaleType, dtype: int64
# =====
# Normal     1088
# Partial     110
# Abnorml      88
# Family       16
# Alloca        8
# AdjLand       4
# Name: SaleCondition, dtype: int64
# =====

# %%
# remove rare caregories

# カテゴリーの少数の変数を'Rare'に変える
# tol→閾値
# n_categories→デフォルト10でこの値以下だと実行されない

rare_enc = RareLabelCategoricalEncoder(tol=0.01, n_categories=5, variables = vars_cat)
rare_enc.fit(X_train)
X_train = rare_enc.transform(X_train)
X_test = rare_enc.transform(X_test)

# %%
for i in vars_cat:
    print(X_train[i].value_counts())
    print("=====")
# Out:
# RL         1036
# RM          197
# FV           55
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64
# =====
# Pave    1309
# Grvl       5
# Name: Street, dtype: int64
# =====
# missing    1233
# Grvl         45
# Pave         36
# Name: Alley, dtype: int64
# =====
# Reg    829
# IR1    440
# IR2     35
# IR3     10
# Name: LotShape, dtype: int64
# =====
# Lvl    1181
# Bnk      56
# HLS      43
# Low      34
# Name: LandContour, dtype: int64
# =====
# AllPub    1313
# NoSeWa       1
# Name: Utilities, dtype: int64
# =====
# Inside     958
# Corner     224
# CulDSac     86
# FR2         43
# FR3          3
# Name: LotConfig, dtype: int64
# =====
# Gtl    1239
# Mod      62
# Sev      13
# Name: LandSlope, dtype: int64
# =====
# NAmes      201
# CollgCr    135
# OldTown    102
# Edwards     88
# Somerst     75
# NridgHt     71
# Gilbert     69
# Sawyer      67
# NWAmes      64
# BrkSide     53
# SawyerW     52
# Mitchel     46
# Crawfor     46
# Timber      36
# NoRidge     35
# IDOTRR      33
# ClearCr     26
# SWISU       24
# StoneBr     23
# Rare        21
# MeadowV     16
# Blmngtn     16
# BrDale      15
# Name: Neighborhood, dtype: int64
# =====
# Norm      1137
# Feedr       71
# Artery      40
# Rare        25
# RRAn        22
# PosN        19
# Name: Condition1, dtype: int64
# =====
# Norm    1303
# Rare      11
# Name: Condition2, dtype: int64
# =====
# 1Fam      1099
# TwnhsE     103
# Duplex      44
# Twnhs       40
# 2fmCon      28
# Name: BldgType, dtype: int64
# =====
# 1Story    652
# 2Story    401
# 1.5Fin    141
# SLvl       60
# Rare       32
# SFoyer     28
# Name: HouseStyle, dtype: int64
# =====
# Gable    1021
# Hip       261
# Rare       32
# Name: RoofStyle, dtype: int64
# =====
# CompShg    1289
# Rare         25
# Name: RoofMatl, dtype: int64
# =====
# VinylSd    463
# HdBoard    197
# Wd Sdng    188
# MetalSd    187
# Plywood    102
# CemntBd     58
# BrkFace     48
# Stucco      24
# WdShing     22
# AsbShng     19
# Rare         6
# Name: Exterior1st, dtype: int64
# =====
# VinylSd    452
# Wd Sdng    183
# HdBoard    183
# MetalSd    182
# Plywood    136
# CmentBd     57
# Wd Shng     33
# BrkFace     24
# Stucco      23
# Rare        22
# AsbShng     19
# Name: Exterior2nd, dtype: int64
# =====
# None       784
# BrkFace    390
# Stone      121
# BrkCmn      13
# missing      6
# Name: MasVnrType, dtype: int64
# =====
# TA    814
# Gd    440
# Ex     47
# Fa     13
# Name: ExterQual, dtype: int64
# =====
# TA    1154
# Gd     130
# Fa      26
# Ex       3
# Po       1
# Name: ExterCond, dtype: int64
# =====
# PConc     575
# CBlock    573
# BrkTil    137
# Slab       21
# Rare        8
# Name: Foundation, dtype: int64
# =====
# TA         589
# Gd         552
# Ex         107
# Fa          34
# missing     32
# Name: BsmtQual, dtype: int64
# =====
# TA         1177
# Gd           60
# Fa           43
# missing      32
# Po            2
# Name: BsmtCond, dtype: int64
# =====
# No         860
# Av         198
# Gd         120
# Mn         103
# missing     33
# Name: BsmtExposure, dtype: int64
# =====
# Unf        393
# GLQ        372
# ALQ        198
# BLQ        135
# Rec        120
# LwQ         64
# missing     32
# Name: BsmtFinType1, dtype: int64
# =====
# Unf        1131
# LwQ          46
# Rec          45
# missing      33
# BLQ          31
# ALQ          17
# Rare         11
# Name: BsmtFinType2, dtype: int64
# =====
# GasA    1284
# GasW      16
# Rare      14
# Name: Heating, dtype: int64
# =====
# Ex    666
# TA    378
# Gd    224
# Fa     45
# Po      1
# Name: HeatingQC, dtype: int64
# =====
# Y    1224
# N      90
# Name: CentralAir, dtype: int64
# =====
# SBrkr    1193
# FuseA      90
# FuseF      26
# Rare        5
# Name: Electrical, dtype: int64
# =====
# TA    664
# Gd    522
# Ex     91
# Fa     37
# Name: KitchenQual, dtype: int64
# =====
# Typ     1223
# Min2      33
# Min1      27
# Rare      16
# Mod       15
# Name: Functional, dtype: int64
# =====
# missing    621
# Gd         339
# TA         284
# Fa          30
# Ex          21
# Po          19
# Name: FireplaceQu, dtype: int64
# =====
# Attchd     782
# Detchd     346
# BuiltIn     83
# missing     74
# Basment     16
# Rare        13
# Name: GarageType, dtype: int64
# =====
# Unf        541
# RFn        383
# Fin        316
# missing     74
# Name: GarageFinish, dtype: int64
# =====
# TA         1178
# missing      74
# Fa           45
# Rare         17
# Name: GarageQual, dtype: int64
# =====
# TA         1190
# missing      74
# Fa           33
# Rare         17
# Name: GarageCond, dtype: int64
# =====
# Y    1201
# N      88
# P      25
# Name: PavedDrive, dtype: int64
# =====
# missing    1308
# Gd            3
# Fa            2
# Ex            1
# Name: PoolQC, dtype: int64
# =====
# missing    1070
# MnPrv       131
# GdPrv        55
# GdWo         48
# MnWw         10
# Name: Fence, dtype: int64
# =====
# missing    1263
# Shed         46
# Othr          2
# Gar2          2
# TenC          1
# Name: MiscFeature, dtype: int64
# =====
# WD      1144
# New      108
# COD       38
# Rare      24
# Name: SaleType, dtype: int64
# =====
# Normal     1088
# Partial     110
# Abnorml      88
# Family       16
# Rare         12
# Name: SaleCondition, dtype: int64
# =====

# %%
# encode with labels

ordinal_enc = OrdinalEncoder()
X_train[vars_cat] = ordinal_enc.fit_transform(X_train[vars_cat])
X_test[vars_cat] = ordinal_enc.transform(X_test[vars_cat])

# %%
[var for var in X_train.columns if X_test[var].isnull().sum()>0]
# Out:
# []

# %%
X_train.head()
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 930    931        20.0       3.0         73.0   8925.0     1.0    2.0
# 656    657        20.0       3.0         72.0  10007.0     1.0    2.0
# 45      46       120.0       3.0         61.0   7658.0     1.0    2.0
# 1348  1349        20.0       3.0         -1.0  16196.0     1.0    2.0
# 55      56        20.0       3.0        100.0  10175.0     1.0    2.0
#
#       LotShape  LandContour  Utilities  LotConfig  LandSlope  Neighborhood  \
# 930        0.0          1.0        0.0        4.0        0.0          22.0
# 656        0.0          3.0        0.0        4.0        0.0          11.0
# 45         3.0          3.0        0.0        4.0        0.0          14.0
# 1348       2.0          2.0        0.0        4.0        0.0          19.0
# 55         0.0          3.0        0.0        4.0        0.0          11.0
#
#       Condition1  Condition2  BldgType  HouseStyle  OverallQual  OverallCond  \
# 930          2.0         0.0       0.0         1.0          8.0          5.0
# 656          2.0         0.0       0.0         1.0          5.0          7.0
# 45           2.0         0.0       4.0         1.0          9.0          5.0
# 1348         2.0         0.0       0.0         1.0          7.0          5.0
# 55           2.0         0.0       0.0         1.0          6.0          5.0
#
#       YearBuilt  YearRemodAdd  RoofStyle  RoofMatl  Exterior1st  Exterior2nd  \
# 930         2.0           2.0        0.0       0.0          8.0          8.0
# 656        49.0           2.0        0.0       0.0          3.0          3.0
# 45          5.0           5.0        1.0       0.0          4.0          4.0
# 1348        9.0           9.0        0.0       0.0          8.0          8.0
# 55         44.0          44.0        0.0       0.0          3.0          5.0
#
#       MasVnrType  MasVnrArea  ExterQual  ExterCond  Foundation  BsmtQual  \
# 930          2.0         0.0        2.0        4.0         2.0       2.0
# 656          1.0        54.0        2.0        4.0         1.0       3.0
# 45           1.0       412.0        0.0        4.0         2.0       0.0
# 1348         2.0         0.0        2.0        4.0         2.0       2.0
# 55           1.0       272.0        3.0        4.0         1.0       3.0
#
#       BsmtCond  BsmtExposure  BsmtFinType1  BsmtFinSF1  BsmtFinType2  \
# 930        3.0           0.0           2.0        16.0           5.0
# 656        3.0           3.0           0.0       806.0           5.0
# 45         3.0           3.0           2.0       456.0           5.0
# 1348       3.0           1.0           2.0      1443.0           5.0
# 55         3.0           3.0           1.0       490.0           5.0
#
#       BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  Heating  HeatingQC  CentralAir  \
# 930          0.0     1450.0       1466.0      0.0        0.0         1.0
# 656          0.0      247.0       1053.0      0.0        0.0         1.0
# 45           0.0     1296.0       1752.0      0.0        0.0         1.0
# 1348         0.0       39.0       1482.0      0.0        0.0         1.0
# 55           0.0      935.0       1425.0      0.0        2.0         1.0
#
#       Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  \
# 930          3.0    1466.0       0.0           0.0     1466.0           0.0
# 656          3.0    1053.0       0.0           0.0     1053.0           1.0
# 45           3.0    1752.0       0.0           0.0     1752.0           1.0
# 1348         3.0    1494.0       0.0           0.0     1494.0           1.0
# 55           3.0    1425.0       0.0           0.0     1425.0           0.0
#
#       BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# 930            0.0       2.0       0.0           3.0           1.0
# 656            0.0       1.0       1.0           3.0           1.0
# 45             0.0       2.0       0.0           2.0           1.0
# 1348           0.0       2.0       0.0           3.0           1.0
# 55             0.0       2.0       0.0           3.0           1.0
#
#       KitchenQual  TotRmsAbvGrd  Functional  Fireplaces  FireplaceQu  \
# 930           2.0           7.0         4.0         0.0          5.0
# 656           2.0           5.0         4.0         0.0          5.0
# 45            0.0           6.0         4.0         1.0          2.0
# 1348          2.0           5.0         4.0         1.0          1.0
# 55            3.0           7.0         4.0         1.0          2.0
#
#       GarageType  GarageYrBlt  GarageFinish  GarageCars  GarageArea  \
# 930          0.0          2.0           0.0         3.0       610.0
# 656          0.0         49.0           1.0         1.0       312.0
# 45           0.0          5.0           1.0         2.0       576.0
# 1348         0.0          9.0           1.0         2.0       514.0
# 55           0.0         44.0           1.0         2.0       576.0
#
#       GarageQual  GarageCond  PavedDrive  WoodDeckSF  OpenPorchSF  \
# 930          2.0         2.0         2.0       100.0         18.0
# 656          2.0         2.0         2.0         0.0          0.0
# 45           2.0         2.0         2.0       196.0         82.0
# 1348         2.0         2.0         2.0       402.0         25.0
# 55           2.0         2.0         2.0         0.0          0.0
#
#       EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  PoolQC  Fence  \
# 930             0.0        0.0          0.0       0.0     3.0    4.0
# 656             0.0        0.0          0.0       0.0     3.0    2.0
# 45              0.0        0.0          0.0       0.0     3.0    4.0
# 1348            0.0        0.0          0.0       0.0     3.0    4.0
# 55              0.0      407.0          0.0       0.0     3.0    4.0
#
#       MiscFeature  MiscVal  MoSold  YrSold  SaleType  SaleCondition
# 930           4.0      0.0     7.0  2009.0       3.0            2.0
# 656           4.0      0.0     8.0  2008.0       3.0            2.0
# 45            4.0      0.0     2.0  2010.0       3.0            2.0
# 1348          4.0      0.0     8.0  2007.0       3.0            2.0
# 55            4.0      0.0     7.0  2008.0       3.0            2.0

# %% [markdown]
# ## Gradient boosting regressor

# %%
import lightgbm as lgb
import xgboost as xgb

tree_reg = GradientBoostingRegressor(random_state=0, n_estimators=50)
#tree_reg = xgb.XGBRegressor(max_depth=6, random_state=0, n_estimators=1000)

tree_reg.fit(X_train, y_train)
# Out:
# /Users/hiroshi/.pyenv/versions/anaconda3-2019.10/lib/python3.7/site-packages/lightgbm/__init__.py:48: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.3) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=50,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=0, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
# evaluate the model:

# We will evaluate performance using the mean squared error and the
# root of the mean squared error

pred = tree_reg.predict(X_train[:])
print('linear train mse: {}'.format(mean_squared_error(y_train, pred)))
print('linear train rmse: {}'.format(sqrt(mean_squared_error(y_train, pred))))
print('linear train mae: {}'.format(mean_absolute_error(y_train, pred)))


print()
pred = tree_reg.predict(X_test[:])
print('linear test mse: {}'.format(mean_squared_error(y_test, pred)))
print('linear test rmse: {}'.format(sqrt(mean_squared_error(y_test, pred))))
print('linear test mae: {}'.format(mean_absolute_error(y_test, pred)))
# Out:
# linear train mse: 319335295.90204245
# linear train rmse: 17869.955117516172
# linear train mae: 12834.284153499842
#
# linear test mse: 1100602976.041241
# linear test rmse: 33175.33686402055
# linear test rmse: 17538.899212032706

# %%
# These are the values produced by our current live model
# we new them from the past, so I pase them here for information

print('''
Prediction analysis from old Lasso Regression:
---------------------------------------------
linear train mse: 1087435415.4414542
linear train rmse: 32976.28565259366

linear test mse: 1405259552.2596064
linear test rmse: 37486.79170400698
''')
# Out:
# Prediction analysis from old Lasso Regression:
# ---------------------------------------------
# linear train mse: 1087435415.4414542
# linear train rmse: 32976.28565259366
#
# linear test mse: 1405259552.2596064
# linear test rmse: 37486.79170400698

# %%
# let's evaluate our predictions respect to the original price

plt.scatter(y_test, tree_reg.predict(X_test))
plt.xlabel('True House Price')
plt.ylabel('Predicted House Price')
plt.title('Evaluation of Lasso Predictions')
# Out:
# Text(0.5, 1.0, 'Evaluation of Lasso Predictions')

# %% [markdown]
# ## Feature Selection

# %%
# here I will do the model fitting and feature selection
# altogether in one line of code

# To select features we use Scikit-learn's SelectFromModel
# specifying the the Gradient Boosting Regressor model

# and we train the SelecgFromModel with the train set.

# remember to set the seed, the random state in this function
sel_ = SelectFromModel(GradientBoostingRegressor(
    random_state=0, n_estimators=50))
sel_.fit(X_train, y_train)


# sel_ = SelectFromModel(lgb.LGBMRegressor(
#     random_state=0, n_estimators=5000))
# sel_.fit(X_train, y_train)
# Out:
# SelectFromModel(estimator=GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0,
#                                                     criterion='friedman_mse',
#                                                     init=None,
#                                                     learning_rate=0.1,
#                                                     loss='ls', max_depth=3,
#                                                     max_features=None,
#                                                     max_leaf_nodes=None,
#                                                     min_impurity_decrease=0.0,
#                                                     min_impurity_split=None,
#                                                     min_samples_leaf=1,
#                                                     min_samples_split=2,
#                                                     min_weight_fraction_leaf=0.0,
#                                                     n_estimators=50,
#                                                     n_iter_no_change=None,
#                                                     presort='deprecated',
#                                                     random_state=0,
#                                                     subsample=1.0, tol=0.0001,
#                                                     validation_fraction=0.1,
#                                                     verbose=0,
#                                                     warm_start=False),
#                 max_features=None, norm_order=1, prefit=False, threshold=None)

# %%
# let's print the number of total and selected features

# this is how we can make a list of the selected features
selected_feat = X_train.columns[(sel_.get_support())]

# let's print some stats
print('total features: {}'.format((X_train.shape[1])))
print('selected features: {}'.format(len(selected_feat)))
# Out:
# total features: 80
# selected features: 10

# %%
selected_feat
# Out:
# Index(['LotArea', 'OverallQual', 'YearRemodAdd', 'BsmtQual', 'BsmtFinSF1',
#        'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'GarageCars'],
#       dtype='object')

# %% [markdown]
# ## Re-build model with selected features

# %%
tree_reg = GradientBoostingRegressor(random_state=0, n_estimators=50)

#tree_reg = xgb.XGBRegressor(random_state=0, n_estimators=5000)

tree_reg.fit(X_train[selected_feat], y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=50,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=0, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
pred = tree_reg.predict(X_train[selected_feat])
print('linear train mse: {}'.format(mean_squared_error(y_train, pred)))
print('linear train rmse: {}'.format(sqrt(mean_squared_error(y_train, pred))))
print('linear train mae: {}'.format(mean_absolute_error(y_train, pred)))


print()
pred = tree_reg.predict(X_test[selected_feat])
print('linear test mse: {}'.format(mean_squared_error(y_test, pred)))
print('linear test rmse: {}'.format(sqrt(mean_squared_error(y_test, pred))))
print('linear test mae: {}'.format(mean_absolute_error(y_test, pred)))
# Out:
# linear train mse: 418644251.8706319
# linear train rmse: 20460.797928493204
# linear train mae: 14567.429897896152
#
# linear test mse: 633153768.8943316
# linear test rmse: 25162.54694768261
# linear test mae: 16571.808768594416

# %%
data[selected_feat].head()
# Out:
#    LotArea  OverallQual  YearRemodAdd BsmtQual  BsmtFinSF1  TotalBsmtSF  \
# 0     8450            7          2003       Gd         706          856
# 1     9600            6          1976       Gd         978         1262
# 2    11250            7          2002       Gd         486          920
# 3     9550            7          1970       TA         216          756
# 4    14260            8          2000       Gd         655         1145
#
#    1stFlrSF  2ndFlrSF  GrLivArea  GarageCars
# 0       856       854       1710           2
# 1      1262         0       1262           2
# 2       920       866       1786           2
# 3       961       756       1717           3
# 4      1145      1053       2198           3

# %%
# make a list of the categorical variables that contain missing values

vars_dates = ['YearRemodAdd']
vars_cat = ['BsmtQual']
vars_num = ['LotArea', 'OverallQual', 'YearRemodAdd', 'BsmtQual', 'BsmtFinSF1',
            'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'GarageCars']
